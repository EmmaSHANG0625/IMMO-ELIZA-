# %%
import pandas as pd 
import pickle

# %%
df = pd.read_csv('./Data for Machine Learning.csv')

del df['Unnamed: 0']

df.to_csv("./Data for Machine Learning_final.csv", index = True)

# %%
del df['Unnamed: 0.1']
del df['Unnamed: 0.2']
df.to_csv("./Data for Machine Learning_final.csv", index = True)

# %%
#change district column names
districts_names = {'district_Tournai': 'Tournai', 
             'district_Brugge': 'Brugge', 
             'district_Veurne': 'Veurne', 
             'district_Mechelen': 'Mechelen', 
             'district_Antwerp': 'Antwerp', 
             'district_Ieper':'Ieper', 
             'district_Mons': 'Mons', 
             'district_Philippeville': 'Philippeville', 
             'district_Brussels': 'Brussels', 
             'district_Soignies': 'Soignies', 
             'district_Charleroi': 'Charleroi', 
             'district_Leuven': 'Leuven', 
             'district_Liège': 'Liège', 
             'district_Aalst': 'Aalst', 
             'district_Sint-Niklaas':'Sint-Niklaas', 
             'district_Verviers': 'Verviers', 
             'district_Marche-en-Famenne': 'Marche-en-Famenne', 
             'district_Kortrijk': 'Kortrijk', 
             'district_Gent': 'Gent', 
             'district_Eeklo': 'Eeklo', 
             'district_Hasselt':'Hasselt', 
             'district_Nivelles': 'Nivelles', 
             'district_Diksmuide': 'Diksmuide', 
             'district_Dendermonde': 'Dendermonde', 
             'district_Huy':'Huy', 
             'district_Tongeren': 'Tongeren', 
             'district_Dinant': 'Dinant', 
             'district_Neufchâteau': 'Neufchâteau', 
             'district_Halle-Vilvoorde': 'Halle-Vilvoorde', 
             'district_Tielt': 'Tielt', 
             'district_Roeselare': 'Roeselare', 
             'district_Namur': 'Namur', 
             'district_Oostend': 'Oostend', 
             'district_Oudenaarde':'Oudenaarde', 
             'district_Thuin': 'Thuin', 
             'district_Arlon': 'Arlon', 
             'district_Turnhout': 'Turnhout', 
             'district_Ath': 'Ath', 
             'district_Maaseik': 'Maaseik', 
             'district_Virton': 'Virton', 
             'district_Bastogne': 'Bastogne', 
             'district_Mouscron': 'Mouscron', 
             'district_Waremme': 'Waremme', 
             'district_Bruge': 'Bruge'}


df = df.rename(columns=districts_names)
df.to_csv("./Data for Machine Learning_final.csv", index = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104442 entries, 0 to 104441
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   bathroom_count               96305 non-null   float64
#  1   bedroom_count                96305 non-null   float64
#  2   construction_year            96305 non-null   float64
#  3   garden                       96305 non-null   float64
#  4   living_area                  96305 non-null   float64
#  5   number_of_facades            96305 non-null   float64
#  6   room_count                   96305 non-null   float64
#  7   surface_of_plot              96305 non-null   float64
#  8   swimming_pool                96305 non-null   float64
#  9   PEB_grade                    96305 non-null   float64
#  10  Building_state_grade         96305 non-null   float64
#  11  price                        96305 non-null   float64
# ...

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87688 entries, 0 to 88723
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   bathroom_count               87688 non-null  float64
#  1   bedroom_count                87688 non-null  float64
#  2   construction_year            87688 non-null  float64
#  3   garden                       87688 non-null  float64
#  4   living_area                  87688 non-null  float64
#  5   number_of_facades            87688 non-null  float64
#  6   room_count                   87688 non-null  float64
#  7   surface_of_plot              87688 non-null  float64
#  8   swimming_pool                87688 non-null  float64
#  9   PEB_grade                    87688 non-null  float64
#  10  Building_state_grade         87688 non-null  float64
#  11  price                        87688 non-null  float64
# ...

# %%
df.to_csv("./Data for Machine Learning_final.csv", index = True)

# %%
df = pd.read_csv('./Data for Machine Learning_final.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# bathroom_count                 0
# bedroom_count                  0
# construction_year              0
# garden                         0
# living_area                    0
# number_of_facades              0
# room_count                     0
# surface_of_plot                0
# swimming_pool                  0
# PEB_grade                      0
# Building_state_grade           0
# price                          0
# type_of_property_appartment    0
# type_of_property_house         0
# Aalst                          0
# Antwerp                        0
# Arlon                          0
# Ath                            0
# Bastogne                       0
# Bruge                          0
# Brugge                         0
# Brussels                       0
# Charleroi                      0
# Dendermonde                    0
# Diksmuide                      0
# Dinant                         0
# Eeklo                          0
# ...
